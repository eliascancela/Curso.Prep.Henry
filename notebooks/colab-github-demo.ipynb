# %% [markdown]
# <a href="https://colab.research.google.com/github/eliascancela/Curso.Prep.Henry/blob/master/notebooks/colab-github-demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Using Google Colab with GitHub

# %% [markdown]
# [Google Colaboratory](http://colab.research.google.com) is designed to integrate cleanly with GitHub, allowing both loading notebooks from github and saving notebooks to github.

# %% [markdown]
# ## Loading Public Notebooks Directly from GitHub
#
# Colab can load public github notebooks directly, with no required authorization step.
#
# For example, consider the notebook at this address: https://github.com/googlecolab/colabtools/blob/master/notebooks/colab-github-demo.ipynb.
#
# The direct colab link to this notebook is: https://colab.research.google.com/github/googlecolab/colabtools/blob/master/notebooks/colab-github-demo.ipynb.
#
# To generate such links in one click, you can use the [Open in Colab](https://chrome.google.com/webstore/detail/open-in-colab/iogfkhleblhcpcekbiedikdehleodpjo) Chrome extension.

# %% [markdown]
# ## Browsing GitHub Repositories from Colab
#
# Colab also supports special URLs that link directly to a GitHub browser for any user/organization, repository, or branch. For example:
#
# - http://colab.research.google.com/github will give you a general github browser, where you can search for any github organization or username.
# - http://colab.research.google.com/github/googlecolab/ will open the repository browser for the ``googlecolab`` organization. Replace ``googlecolab`` with any other github org or user to see their repositories.
# - http://colab.research.google.com/github/googlecolab/colabtools/ will let you browse the main branch of the ``colabtools`` repository within the ``googlecolab`` organization. Substitute any user/org and repository to see its contents.
# - http://colab.research.google.com/github/googlecolab/colabtools/blob/master will let you browse ``master`` branch of the ``colabtools`` repository within the ``googlecolab`` organization. (don't forget the ``blob`` here!) You can specify any valid branch for any valid repository.

# %% [markdown]
# ## Loading Private Notebooks
#
# Loading a notebook from a private GitHub repository is possible, but requires an additional step to allow Colab to access your files.
# Do the following:
#
# 1. Navigate to http://colab.research.google.com/github.
# 2. Click the "Include Private Repos" checkbox.
# 3. In the popup window, sign-in to your Github account and authorize Colab to read the private files.
# 4. Your private repositories and notebooks will now be available via the github navigation pane.

# %% [markdown]
# ## Saving Notebooks To GitHub or Drive
#
# Any time you open a GitHub hosted notebook in Colab, it opens a new editable view of the notebook. You can run and modify the notebook without worrying about overwriting the source.
#
# If you would like to save your changes from within Colab, you can use the File menu to save the modified notebook either to Google Drive or back to GitHub. Choose **File→Save a copy in Drive** or **File→Save a copy to GitHub** and follow the resulting prompts. To save a Colab notebook to GitHub requires giving Colab permission to push the commit to your repository.

# %% [markdown]
# ## Open In Colab Badge
#
# Anybody can open a copy of any github-hosted notebook within Colab. To make it easier to give people access to live views of GitHub-hosted notebooks,
# colab provides a [shields.io](http://shields.io/)-style badge, which appears as follows:
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/googlecolab/colabtools/blob/master/notebooks/colab-github-demo.ipynb)
#
# The markdown for the above badge is the following:
#
# ```markdown
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/googlecolab/colabtools/blob/master/notebooks/colab-github-demo.ipynb)
# ```
#
# The HTML equivalent is:
#
# ```HTML
# <a href="https://colab.research.google.com/github/googlecolab/colabtools/blob/master/notebooks/colab-github-demo.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
# ```
#
# Remember to replace the notebook URL in this template with the notebook you want to link to.

# %%
a=np.array([1,2,3],
 [1,2,3],
  [1,2,3])
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-34eabd63395b> in <cell line: 0>()
# ----> 1 a=np.array([1,2,3],
#       2  [1,2,3],
#       3   [1,2,3])
#       4 a
#
# NameError: name 'np' is not defined

# %%
import sys

# %%
import numpy as np
a=np.array([[1,2,3],
 [1,2,3],
  [1,2,3]])
a
# Out:
# array([[1, 2, 3],
#        [1, 2, 3],
#        [1, 2, 3]])

# %%
a.shape
a.dtype
# Out:
# dtype('int64')

# %%
# prompt: crear una matriz de 9 por 9 con los primeros 81 numeros primos  escritos cada uno en base el numero primo anterior

import numpy as np

def is_prime(num):
  """Checks if a number is prime."""
  if num <= 1:
    return False
  for i in range(2, int(num**0.5) + 1):
    if num % i == 0:
      return False
  return True

def to_base(num, base):
  """Converts a number to a given base."""
  if num == 0:
    return "0"
  digits = []
  while num > 0:
    digits.append(str(num % base))
    num //= base
  return "".join(digits[::-1])

def create_prime_matrix():
  """Creates a 9x9 matrix with the first 81 prime numbers."""
  primes = []
  num = 2
  while len(primes) < 81:
    if is_prime(num):
      primes.append(num)
    num += 1

  matrix = np.zeros((9, 9), dtype=object)  # Use object dtype to store strings

  for i in range(9):
    for j in range(9):
      index = i * 9 + j
      if index > 0:
          matrix[i, j] = to_base(primes[index], primes[index-1])
      else:
          matrix[i,j] = str(primes[index])

  return matrix

prime_matrix = create_prime_matrix()
prime_matrix
# Out:
# array([['2', '11', '12', '12', '14', '12', '14', '12', '14'],
#        ['16', '12', '16', '14', '12', '14', '16', '16', '12'],
#        ['16', '14', '12', '16', '14', '16', '18', '14', '12'],
#        ['14', '12', '14', '114', '14', '16', '12', '110', '12'],
#        ['16', '16', '14', '16', '16', '12', '110', '12', '14'],
#        ['12', '112', '112', '14', '12', '14', '16', '12', '110'],
#        ['16', '16', '16', '12', '16', '14', '12', '110', '114'],
#        ['14', '12', '14', '114', '16', '110', '12', '14', '16'],
#        ['18', '16', '16', '14', '16', '18', '14', '18', '110']],
#       dtype=object)

# %%
escribir lo primeros 100 numeros primos en base 5
# Out:
#   File "<ipython-input-14-1c161b230074>", line 1
#     escribir lo primeros 100 numeros primos en base 5
#              ^
# SyntaxError: invalid syntax

# %%
# prompt: escribir lo primeros 100 numeros primos en base 5

def is_prime(num):
    """Checks if a number is prime."""
    if num <= 1:
        return False
    for i in range(2, int(num**0.5) + 1):
        if num % i == 0:
            return False
    return True

def to_base_5(n):
    if n == 0:
        return "0"
    nums = []
    while n:
        n, r = divmod(n, 5)
        nums.append(str(r))
    return "".join(reversed(nums))

primes = []
num = 2
while len(primes) < 100:
    if is_prime(num):
        primes.append(num)
    num += 1

for p in primes:
  print(f"{p} in base 5 is {to_base_5(p)}")
# Out:
# 2 in base 5 is 2
# 3 in base 5 is 3
# 5 in base 5 is 10
# 7 in base 5 is 12
# 11 in base 5 is 21
# 13 in base 5 is 23
# 17 in base 5 is 32
# 19 in base 5 is 34
# 23 in base 5 is 43
# 29 in base 5 is 104
# 31 in base 5 is 111
# 37 in base 5 is 122
# 41 in base 5 is 131
# 43 in base 5 is 133
# 47 in base 5 is 142
# 53 in base 5 is 203
# 59 in base 5 is 214
# 61 in base 5 is 221
# 67 in base 5 is 232
# 71 in base 5 is 241
# 73 in base 5 is 243
# 79 in base 5 is 304
# 83 in base 5 is 313
# 89 in base 5 is 324
# 97 in base 5 is 342
# 101 in base 5 is 401
# 103 in base 5 is 403
# 107 in base 5 is 412
# 109 in base 5 is 414
# 113 in base 5 is 423
# 127 in base 5 is 1002
# 131 in base 5 is 1011
# 137 in base 5 is 1022
# 139 in base 5 is 1024
# 149 in base 5 is 1044
# 151 in base 5 is 1101
# 157 in base 5 is 1112
# 163 in base 5 is 1123
# 167 in base 5 is 1132
# 173 in base 5 is 1143
# 179 in base 5 is 1204
# 181 in base 5 is 1211
# 191 in base 5 is 1231
# 193 in base 5 is 1233
# ...

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
LP = pd.read_csv("1001 Albums You Must Hear Before You Die.csv")

# %%
LP.head()
# Out:
#     ✓                Album Title          Artist  Release Date  Unnamed: 4  \
# 0 NaN     In The Wee Small Hours   Frank Sinatra          1955         NaN
# 1 NaN          Birth of the Cool     Miles Davis          1956         NaN
# 2 NaN   Ellington at Newport '56  Duke Ellington          1956         NaN
# 3 NaN              Elvis Presley   Elvis Presley          1956         NaN
# 4 NaN  Songs For Swingin' Lovers   Frank Sinatra          1956         NaN
#
#    Year  Number of Albums
# 0  1955                1.0
# 1  1956                5.0
# 2  1957                8.0
# 3  1958                4.0
# 4  1959                5.0

# %%
# prompt: Mediante el marco de datos LP: cantidad de discos cuyo valor date sea mayor que 1980

# Import necessary libraries if not already imported
import pandas as pd

# Assuming your dataframe is named 'LP'

# Filter the dataframe to include only rows where 'Release Date' is greater than 1980
filtered_LP = LP[LP['Release Date'] > 1980]

# Calculate the number of rows in the filtered dataframe, which represents the number of records with 'Release Date' greater than 1980
num_records = len(filtered_LP)

# Print the result
print(f"The number of albums with release date greater than 1980 is {num_records}")
# Out:
# The number of albums with release date greater than 1980 is 524

# %%
Speed_df = df[df['Speed']<=10]
slow_pokemons_df = len(Speed_df)

# Print the result
print(f" {slow_pokemons_df}")

# %%
# @title Release Date

from matplotlib import pyplot as plt
LP['Release Date'].plot(kind='hist', bins=20, title='Release Date')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# prompt: seleccionar solo discos de la lista de los beatles

import pandas as pd

# Assuming your dataframe is named 'LP'
# and it has been loaded from the CSV file as in the provided code

# Filter for albums by the Beatles
beatles_albums = LP[LP['Artist'] == 'The Beatles']

# Display the filtered dataframe
beatles_albums
# Out:
#       ✓                           Album Title       Artist  Release Date  \
# 38  NaN                      With The Beatles  The Beatles          1963
# 40  NaN                    A Hard Day's Night  The Beatles          1964
# 57  NaN                           Rubber Soul  The Beatles          1965
# 71  NaN                              Revolver  The Beatles          1966
# 94  NaN  Sgt Pepper's Lonely Hearts Club Band  The Beatles          1967
# 125 NaN             The Beatles (White Album)  The Beatles          1968
# 136 NaN                            Abbey Road  The Beatles          1969
#
#      Unnamed: 4  Year  Number of Albums
# 38          NaN  1993               27.0
# 40          NaN  1995               23.0
# 57          NaN   NaN                NaN
# 71          NaN   NaN                NaN
# 94          NaN   NaN                NaN
# 125         NaN   NaN                NaN
# 136         NaN   NaN                NaN

# %%
# prompt: seleccionar solo discos de la lista de los beatles

import pandas as pd

# Assuming your dataframe is named 'LP'
# and it has been loaded from the CSV file as in the provided code

# Filter for albums by the Beatles
N1973_albums = LP[LP['Release Date'] == 1973]

# Display the filtered dataframe
N1973_albums
# Out:
#       ✓                    Album Title                                 Artist  \
# 268 NaN                            3+3                         The Isley Bros
# 269 NaN          A Wizard, A True Star                          Todd Rundgren
# 270 NaN                   Aladdin Sane                            David Bowie
# 271 NaN                Band On The Run                 Paul McCartney & Wings
# 272 NaN                         Berlin                               Lou Reed
# 273 NaN          Billion Dollar Babies                           Alice Cooper
# 274 NaN                     Bongo Rock  Michael Viner's Incredible Bongo Band
# 275 NaN                   Catch A Fire               Bob Marley & The Wailers
# 276 NaN           Countdown to Ecstasy                             Steely Dan
# 277 NaN          Dark Side of the Moon                             Pink Floyd
# 278 NaN                       Faust IV                                  Faust
# ...

# %%
# prompt: cual es el  nombre del album de la lista que  pertenece a la banda ZZ Top y que fue editadoen 1973?

# Assuming your dataframe is named 'LP'
# and it has been loaded from the CSV file as in the provided code

# Filter for albums by ZZ Top released in 1973
zz_top_1973_albums = LP[(LP['Artist'] == 'ZZ Top') & (LP['Release Date'] == 1973)]

# Extract the album name(s)
album_names = zz_top_1973_albums['Album Title']

# Print the album name(s)
album_names
# Out:
# 298    Tres Hombres
# Name: Album Title, dtype: object

# %%
# prompt: cuantos discos fueron editados en 1996

# Assuming your dataframe is named 'LP'
# and it has been loaded from the CSV file as in the provided code

# Filter for albums released in 1996
albums_1996 = LP[LP['Release Date'] == 1996]

# Calculate the number of albums released in 1996
num_albums_1996 = len(albums_1996)

# Print the result
print(f"The number of albums released in 1996 is: {num_albums_1996}")
# Out:
# The number of albums released in 1996 is: 29

# %%
cuantos discos fueron editados despues de 1970 y antes de 1980
# Out:
#   File "<ipython-input-17-d1a223cd654d>", line 1
#     cuantos discos fueron editados despues de 1970 y antes de 1980
#             ^
# SyntaxError: invalid syntax

# %%
# prompt: cuantos discos fueron editados despues de 1970 y antes de 1980

# Assuming your dataframe is named 'LP'
# and it has been loaded from the CSV file as in the provided code

# Filter for albums released between 1970 and 1980 (exclusive of 1980)
albums_1970s = LP[(LP['Release Date'] > 1970) & (LP['Release Date'] < 1980)]

# Calculate the number of albums released in the 1970s
num_albums_1970s = len(albums_1970s)

# Print the result
print(f"The number of albums released between 1971 and 1979 is: {num_albums_1970s}")

# %%
# prompt: seleccionar solo discos de la lista de los beatles

import pandas as pd

# Assuming your dataframe is named 'LP'
# and it has been loaded from the CSV file as in the provided code

# Filter for albums by the Beatles
N1998_albums = LP[LP['Release Date'] == 1998]

# Display the filtered dataframe
N1998_albums
# Out:
#       ✓                                        Album Title  \
# 859 NaN                                   Apocalypse Dudes
# 860 NaN  Bob Dylan Live 1966 ('Royal Albert Hall' Bootleg)
# 861 NaN                        Car Wheels On A Gravel Road
# 862 NaN                                     Celebrity Skin
# 863 NaN                                        Clandestino
# 864 NaN                                   Deserter's Songs
# 865 NaN                              Devil Without A Cause
# 866 NaN                                  Follow the Leader
# 867 NaN                                   I See A Darkness
# 868 NaN                                              Kenza
# 869 NaN                                     Mermaid Avenue
# 870 NaN                                        Moon Safari
# 871 NaN                    Music Has the Right to Children
# 872 NaN                                                 OK
# 873 NaN                            Queens Of The Stone Age
# ...

# %%
# prompt: seleccionar solo discos de la lista de los beatles

import pandas as pd

# Assuming your dataframe is named 'LP'
# and it has been loaded from the CSV file as in the provided code

# Filter for albums by the Beatles
N1999_albums = LP[LP['Release Date'] == 1999]

# Display the filtered dataframe
N1999_albums
# Out:
#       ✓           Album Title                  Artist  Release Date  \
# 880 NaN         69 Love Songs     The Magnetic Fields          1999
# 881 NaN        Agaetis Byrjun               Sigur Ros          1999
# 882 NaN    Apple Venus Vol. 1                     XTC          1999
# 883 NaN           Beyond Skin           Nitin Sawhney          1999
# 884 NaN       Californication   Red Hot Chili Peppers          1999
# 885 NaN   Central Reservation              Beth Orton          1999
# 886 NaN            Darkdancer  Les Rhythmes Digitales          1999
# 887 NaN             HMS Fable                   Shack          1999
# 888 NaN              Le Tigre                Le Tigre          1999
# 889 NaN         Make Yourself                 Incubus          1999
# 890 NaN                  Play                    Moby          1999
# 891 NaN                Remedy           Basement Jaxx          1999
# 892 NaN                   S&M               Metallica          1999
# ...

# %%
# prompt: seleccionar solo discos de la lista de los beatles

import pandas as pd

# Assuming your dataframe is named 'LP'
# and it has been loaded from the CSV file as in the provided code

# Filter for albums by the Beatles
N1997_albums = LP[LP['Release Date'] == 1997]

# Display the filtered dataframe
N1997_albums
# Out:
#       ✓                                     Album Title  \
# 836 NaN                        A Short Album About Love
# 837 NaN                                            Blur
# 838 NaN                         Buena Vista Social Club
# 839 NaN                                       Butterfly
# 840 NaN                                      Dig Me Out
# 841 NaN                               Dig Your Own Hole
# 842 NaN                                       Either/Or
# 843 NaN                                        Homework
# 844 NaN                             In It For The Money
# 845 NaN  Ladies And Gentlemen, We Are Floating in Space
# 846 NaN                                Let's Get Killed
# 847 NaN                                Life Thru A Lens
# 848 NaN                               Maverick A Strike
# 849 NaN                                       New Forms
# 850 NaN                                     OK Computer
# 851 NaN                                         Schleep
# ...

# %%
# prompt: seleccionar solo discos de la lista de los beatles

import pandas as pd

# Assuming your dataframe is named 'LP'
# and it has been loaded from the CSV file as in the provided code

# Filter for albums by the Beatles
N1996_albums = LP[LP['Release Date'] == 1996]

# Display the filtered dataframe
N1996_albums
# Out:
#       ✓                         Album Title                       Artist  \
# 807 NaN                                1977                          Ash
# 808 NaN                Antichrist Superstar               Marilyn Manson
# 809 NaN                     Beautiful Freak                     The Eels
# 810 NaN                         Being There                        Wilco
# 811 NaN     Better Living Through Chemistry                  Fatboy Slim
# 812 NaN                            Casanova            The Divine Comedy
# 813 NaN                  Come Find Yourself     The Fun Lovin' Criminals
# 814 NaN                 Dr Octagonecologyst                   Dr Octagon
# 815 NaN                                Dust              Screaming Trees
# 816 NaN              Emperor Tomato Ketchup                    Stereolab
# 817 NaN                     Endtroducing...                    DJ Shadow
# 818 NaN                  Everything Must Go   The Manic Street Preachers
# ...

# %%
# prompt: seleccionar solo discos de la lista de los beatles

import pandas as pd

# Assuming your dataframe is named 'LP'
# and it has been loaded from the CSV file as in the provided code

# Filter for albums by the Beatles
N2000_albums = LP[LP['Release Date'] == 2000]

# Display the filtered dataframe
N2000_albums
# Out:
#       ✓                                  Album Title           Artist  \
# 899 NaN              All That You Can't Leave Behind               U2
# 900 NaN                                Felt Mountain        Goldfrapp
# 901 NaN                                     Figure 8    Elliott Smith
# 902 NaN                                 Heartbreaker       Ryan Adams
# 903 NaN                                        Kid A        Radiohead
# 904 NaN                     Like Water For Chocolate           Common
# 905 NaN                                   Lost Souls        The Doves
# 906 NaN                                   Mama's Gun      Erykah Badu
# 907 NaN                                        Music          Madonna
# 908 NaN                                        Nixon         Lambchop
# 909 NaN                        Our Aim is to Satisfy      Red Snapper
# 910 NaN                                   Parachutes         Coldplay
# ...
